# %% [markdown]
# # Lorenz attractor predictions using Reservoir Computing based on **NVAR** (*nonlinear vector autoregression*)
#
# *Reference:* "Next generation reservoir computing", Gauthier *et al.* (2021), https://www.nature.com/articles/s41467-021-25801-2

# %%
import matplotlib.pyplot as plt
import numpy as np

from reservoirpy.datasets import lorenz
from reservoirpy.observables import nrmse
from reservoirpy.nodes import Ridge, NVAR

import time as time
import pandas as pd
from IPython.display import Image

# %% [markdown]
# ### Implementation using *ReservoirPy*, a Python library (based on *NumPy* and *SciPy*) that allows to implement Reservoir Computing architectures
#
# https://reservoirpy.readthedocs.io/en/latest/index.html
#
# https://github.com/reservoirpy/reservoirpy
#
# - As for the reservoir node of the RC architecture, we use the ReservoirPy's **NVAR** node, a Nonlinear Vector AutoRegressive machine implemented as described in *Reference*.
#
# ***
#
# The state $\mathbb{O}_{total}$ of the NVAR first contains a serie of linear features $\mathbb{O}_{lin}$ made of input data concatenated with delayed inputs:
#
# $$
# \mathbb{O}_{lin}[t] = \mathbf{X}[t] \oplus \mathbf{X}[t - s] \oplus \mathbf{X}[t - 2s] \oplus \dots \oplus \mathbf{X}[t - (k-1)s]
# $$
#
# where $\mathbf{X}[t]$ are the inputs at time $t$, $k$ is the delay and $s$ is the strides (only one input every $s$ inputs within the delayed inputs is used). The operator $\oplus$ denotes the concatenation.
#
# In addition to these linear features, nonlinear representations $\mathbb{O}_{nonlin}^n$ of the inputs are contructed using all unique monomials of order $n$ of these inputs:
#
# $$
# \mathbb{O}_{nonlin}^n[t] = \mathbb{O}_{lin}[t] \otimes \mathbb{O}_{lin}[t] \overbrace{\otimes \dots \otimes}^{n-1~\mathrm{times}} \mathbb{O}_{lin}[t]
# $$
#
# where $\otimes$ is the operator denoting an outer product followed by the selection of all unique monomials generated by this outer product. Under the hood, this product is computed by ReservoirPy by finding all unique combinations of input features and multiplying each combination of terms.
#
# Finally, all representations are gathered to form the final feature vector $\mathbb{O}_{total}$:
#
# $$
# \mathbb{O}_{total} = \mathbb{O}_{lin}[t] \oplus \mathbb{O}_{nonlin}^n[t]
# $$
#
# ***
#
# - As for the offline readout node of the RC architecture, we use the ReservoirPy's **Ridge** node, a single layer of neurons whose readout weights are learned through Tikhonov linear regression using $\mathbb{O}_{total}$.

# %%
def Plot1D(X, titl1, titl2, titl3, start, pt_number, lw):
    xs, ys, zs = X[:,0], X[:,1], X[:,2]

    fig, (ax1, ax2, ax3) = plt.subplots(3,1, figsize = (15, 15))

    ax1.plot(xs[start:start+pt_number], lw=lw)
    ax1.set_title(titl1)
    ax1.set_xlabel("time")
    ax1.set_ylabel("X Axis")

    ax2.plot(ys[start:start+pt_number], lw=lw)
    ax2.set_title(titl2)
    ax2.set_xlabel("time")
    ax2.set_ylabel("Y Axis")

    ax3.plot(zs[start:start+pt_number], lw=lw)
    ax3.set_title(titl3)
    ax3.set_xlabel("time")
    ax3.set_ylabel("Z axis")

    plt.show()

# %%
def Plot2D(X, titl1, titl2, titl3, start, pt_number, lw, N, color):
    xs, ys, zs = X[:,0], X[:,1], X[:,2]
    fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize = (15, 5))

    ax1.set_title(titl1)
    ax1.set_xlabel("X Axis")
    ax1.set_ylabel("Y Axis")

    ax2.set_title(titl2)
    ax2.set_xlabel("X Axis")
    ax2.set_ylabel("Z Axis")

    ax3.set_title(titl3)
    ax3.set_xlabel("Y Axis")
    ax3.set_ylabel("Z Axis")

    if color:
        cmap = plt.cm.magma#plt.cm.winter
        for i in range(N-1):
            ax1.plot(X[i:i+2, 0], X[i:i+2, 1], color=cmap(255*i//N), lw=lw)
            ax2.plot(X[i:i+2, 0], X[i:i+2, 2], color=cmap(255*i//N), lw=lw)
            ax3.plot(X[i:i+2, 1], X[i:i+2, 2], color=cmap(255*i//N), lw=lw)
    else:
        ax1.plot(xs[start:start+pt_number], ys[start:start+pt_number], lw=lw)
        ax2.plot(xs[start:start+pt_number], zs[start:start+pt_number], lw=lw)
        ax3.plot(ys[start:start+pt_number], zs[start:start+pt_number], lw=lw)

    plt.show()

# %%
def plot3D(X, title, pt_number, N, color, start, lw):
    xs, ys, zs = X[:,0], X[:,1], X[:,2]
    fig = plt.figure(figsize=(10, 10))
    ax  = fig.add_subplot(111, projection='3d')
    ax.set_title(title)
    ax.set_xlabel("X Axis")
    ax.set_ylabel("Y Axis")
    ax.set_zlabel("Z Axis")
    ax.grid(False)

    if color:
        cmap = plt.cm.magma#plt.cm.winter
        for i in range(N-1):
            ax.plot(X[i:i+2, 0], X[i:i+2, 1], X[i:i+2, 2], color=cmap(255*i//N), lw=1.0)
    else:
        ax.plot(xs[start:start+pt_number], ys[start:start+pt_number], zs[start:start+pt_number], lw=lw)

    plt.show()

# %% [markdown]
# ## 0. Generate Lorenz attractor timeseries
#
# $$
# \begin{split}
# \dot{x} &= \sigma(y-x)\\
# \dot{y} &= x(\rho-z)-y\\
# \dot{z} &= xy - \beta z
# \end{split}
# $$

# %%
def lorenz_inside(x, y, z, sigma, rho, beta):
    """
    Given:
    x, y, z: a point of interest in three dimensional space
    sigma, rho, beta: parameters defining the lorenz attractor
    Returns:
    x_dot, y_dot, z_dot: values of the lorenz attractor's partial
    derivatives at the point x, y, z
    """
    x_dot = sigma*(y - x)
    y_dot = rho*x - y - x*z
    z_dot = x*y - beta*z
    return x_dot, y_dot, z_dot

def lorenz_generation(steps, rho, sigma, beta, x0, h, method, select_f):
    t1 = time.time() #times the computation

    if select_f == 1:
        # Need one more for the initial values
        xs = np.empty(steps + 1)
        ys = np.empty(steps + 1)
        zs = np.empty(steps + 1)
        # Set initial values
        xs[0], ys[0], zs[0] = x0[0], x0[1], x0[2]
        # Step through "time", calculating the partial derivatives at the current point
        # and using them to estimate the next point
        for i in range(steps):
            x_dot, y_dot, z_dot = lorenz_inside(xs[i], ys[i], zs[i], sigma, rho, beta)
            xs[i + 1] = xs[i] + (x_dot * h)
            ys[i + 1] = ys[i] + (y_dot * h)
            zs[i + 1] = zs[i] + (z_dot * h)
        X = np.array([xs, ys, zs])
        t2 = time.time()
        return X.T, xs, ys, zs
        print ('computation took ',t2-t1,' seconds.')

    if (select_f == 2):# or (h > 0.01):
        X = lorenz(steps, rho=rho, sigma=sigma, beta=beta, x0=x0, h=h, method = method, atol = atol, rtol = rtol)
        xs, ys, zs = X[:,0], X[:,1], X[:,2]
        t2 = time.time()
        return X, xs, ys, zs
        #print ('computation took ',t2-t1,' seconds.')

# %%
dt         = 0.001 # time step duration (in time unit)
train_time = 20.   # training time (in time unit) # was 10.
test_time  = 200.  # testing time (idem) # was 185
warm_time  = 25.    # warmup time (idem): should always be > k * s # was 5

# discretization
train_steps = round(train_time / dt)
test_steps  = round(test_time  / dt)
warm_steps  = round(warm_time  / dt)

# %%
# Lorenz parameters
n_timesteps = train_steps + test_steps + warm_steps
rho    =  28
sigma  = 10
beta   = 8/3
x0     = [-8, 8, 27]
method = 'LSODA' # https://docs.scipy.org/doc/scipy/reference/generated/scipy.integrate.solve_ivp.html
atol = np.ones(3) * 1e-12
rtol = 1e-12

X, xs, ys, zs = lorenz_generation(n_timesteps, rho, sigma, beta, x0=x0, h=dt, method=method, select_f=2)

lorenz_df = pd.DataFrame(X, columns=['x', 'y', 'z'])
lorenz_df
# Out:
#                x         y          z
# 0      -8.000000  8.000000  27.000000
# 1      -7.840879  7.983553  26.864883
# 2      -7.683508  7.966251  26.731519
# 3      -7.527880  7.948146  26.599891
# 4      -7.373985  7.929292  26.469981
# ...          ...       ...        ...
# 244995  3.658175  6.461821  11.823847
# 244996  3.686335  6.514749  11.816153
# 244997  3.714743  6.568110  11.808860
# 244998  3.743403  6.621906  11.801972
# 244999  3.772314  6.676139  11.795495
#
# [245000 rows x 3 columns]

# %%
plot3D(X, title = "Lorenz attractor (1963)", start=0, pt_number = n_timesteps, N = n_timesteps, color=False, lw = 0.5)

# %%
Plot2D(X, "Lorenz attractor - XY", "Lorenz attractor - XZ", "Lorenz attractor - YZ", start=0, pt_number=n_timesteps, lw=0.5, N = n_timesteps, color=False)

# %%
Plot1D(np.array([xs, ys, zs]).T, "Lorenz attractor - X", "Lorenz attractor - Y", "Lorenz attractor - Z", start=0, pt_number=n_timesteps, lw=0.2)

# %% [markdown]
# ## 1. NVAR for 3D Lorenz attractor forecasting

# %% [markdown]
# Let's define an NVAR with:
#
# - delay $k=2$
# - strides $s=1$
# - order $n=2$
#
# Therefore, the final feature vector $\mathbb{O}_{total}$ will be the following:
#
# $$
# \mathbb{O}_{total}[t] = \mathbb{O}_{lin}[t] \oplus \mathbb{O}_{nonlin}[t]
# $$
#
# where
#
# $$
# \begin{align}
# \mathbb{O}_{lin}[t] &=
#     \begin{bmatrix}
#          x_t\\y_t\\z_t\\x_{t-1}\\y_{t-1}\\z_{t-1}
#     \end{bmatrix}
# &
# \mathbb{O}_{nonlin}[t] &=
#     \begin{bmatrix}
#        x_t^2\\x_t y_t\\x_t z_t\\x_t x_{t-1}\\x_t y_{t-1}\\x_t
#        z_{t-1}\\y_t^2\\y_t z_t\\y_t x_{t-1}\\y_t y_{t-1}\\y_t z_{t-1}\\z_t^2\\z_t x_{t-1}\\z_t y_{t-1}\\z_t
#        z_{t-1}\\x_{t-1}^2\\x_{t-1} y_{t-1}\\x_{t-1} z_{t-1}\\y_{t-1}^2\\y_{t-1} z_{t-1}\\z_{t-1}^2
#     \end{bmatrix}
# \end{align}
# $$
#
# Then, let's connect the NVAR to a readout layer with offline learning using Tikhonov linear regression (Ridge regularization).

# %%
nvar = NVAR(delay=3, order=2, strides=5)
readout = Ridge(output_dim=3, ridge=2.5e-3)# ridge was 2.5e-6

model = nvar >> readout

# %% [markdown]
# https://github.com/reservoirpy/reservoirpy/tree/master/.github/workflowsNow, let's train the model to perform one-step-ahead prediction, i.e., to infer the value of $\mathbf{X}[t+1]$ knowing the value of $\mathbf{X}[t]$.

# %%
X_train  = X[:train_steps+warm_steps-1]
Y_train  = X[1:train_steps+warm_steps]

model = model.fit(X_train, Y_train, warmup=warm_steps)
# Out:
# Running Model-0:   0%|                                    | 0/1 [00:00<?, ?it/s]
# Running Model-0:   0%|                                    | 0/1 [00:00<?, ?it/s]
# Running Model-0: 62it [00:00, 617.11it/s]
# Running Model-0: 146it [00:00, 747.73it/s]
# Running Model-0: 221it [00:00, 645.55it/s]
# Running Model-0: 303it [00:00, 703.88it/s]
# Running Model-0: 375it [00:00, 549.03it/s]
# Running Model-0: 435it [00:00, 551.97it/s]
# Running Model-0: 494it [00:00, 498.50it/s]
# Running Model-0: 547it [00:01, 460.59it/s]
# Running Model-0: 595it [00:01, 409.04it/s]
# Running Model-0: 676it [00:01, 505.14it/s]
# Running Model-0: 741it [00:01, 533.86it/s]
# Running Model-0: 798it [00:01, 458.69it/s]
# Running Model-0: 887it [00:01, 561.97it/s]
# Running Model-0: 968it [00:01, 613.75it/s]
# Running Model-0: 1034it [00:01, 524.97it/s]
# Running Model-0: 1092it [00:02, 524.46it/s]
# Running Model-0: 1173it [00:02, 590.12it/s]
# Running Model-0: 1242it [00:02, 610.85it/s]
# Running Model-0: 1319it [00:02, 650.86it/s]
# Running Model-0: 1387it [00:02, 651.01it/s]
# Running Model-0: 1454it [00:02, 612.41it/s]
# Running Model-0: 1517it [00:02, 610.05it/s]
# Running Model-0: 1588it [00:02, 620.81it/s]
# Running Model-0: 1651it [00:02, 577.82it/s]
# Running Model-0: 1710it [00:03, 538.36it/s]
# Running Model-0: 1783it [00:03, 587.43it/s]
# Running Model-0: 1847it [00:03, 599.15it/s]
# Running Model-0: 1908it [00:03, 537.13it/s]
# Running Model-0: 2013it [00:03, 660.36it/s]
# Running Model-0: 2098it [00:03, 709.42it/s]
# Running Model-0: 2172it [00:03, 646.73it/s]
# Running Model-0: 2240it [00:03, 560.90it/s]
# Running Model-0: 2300it [00:04, 535.17it/s]
# Running Model-0: 2356it [00:04, 511.83it/s]
# Running Model-0: 2409it [00:04, 462.61it/s]
# Running Model-0: 2457it [00:04, 363.28it/s]
# Running Model-0: 2514it [00:04, 401.82it/s]
# Running Model-0: 2586it [00:04, 474.15it/s]
# Running Model-0: 2684it [00:04, 598.57it/s]
# Running Model-0: 2789it [00:04, 714.92it/s]
# Running Model-0: 2888it [00:05, 789.21it/s]
# Running Model-0: 2972it [00:05, 714.76it/s]
# Running Model-0: 3049it [00:05, 611.63it/s]
# Running Model-0: 3116it [00:05, 555.51it/s]
# Running Model-0: 3176it [00:05, 509.06it/s]
# Running Model-0: 3248it [00:05, 546.77it/s]
# Running Model-0: 3326it [00:05, 598.96it/s]
# Running Model-0: 3390it [00:06, 545.85it/s]
# Running Model-0: 3448it [00:06, 513.96it/s]
# Running Model-0: 3536it [00:06, 603.83it/s]
# Running Model-0: 3609it [00:06, 635.49it/s]
# Running Model-0: 3677it [00:06, 647.51it/s]
# Running Model-0: 3745it [00:06, 634.49it/s]
# Running Model-0: 3810it [00:06, 485.55it/s]
# Running Model-0: 3865it [00:06, 441.83it/s]
# Running Model-0: 3986it [00:07, 615.16it/s]
# Running Model-0: 4066it [00:07, 659.40it/s]
# Running Model-0: 4140it [00:07, 658.39it/s]
# Running Model-0: 4211it [00:07, 664.42it/s]
# Running Model-0: 4281it [00:07, 663.59it/s]
# Running Model-0: 4350it [00:07, 579.36it/s]
# Running Model-0: 4433it [00:07, 642.13it/s]
# Running Model-0: 4556it [00:07, 798.31it/s]
# Running Model-0: 4720it [00:07, 1029.85it/s]
# Running Model-0: 4835it [00:08, 1063.14it/s]
# Running Model-0: 4946it [00:08, 1075.85it/s]
# Running Model-0: 5073it [00:08, 1108.86it/s]
# Running Model-0: 5186it [00:08, 923.42it/s]
# Running Model-0: 5285it [00:08, 875.00it/s]
# Running Model-0: 5378it [00:08, 847.02it/s]
# Running Model-0: 5466it [00:08, 781.45it/s]
# Running Model-0: 5648it [00:08, 1039.66it/s]
# Running Model-0: 5791it [00:08, 1141.44it/s]
# Running Model-0: 5929it [00:09, 1206.02it/s]
# Running Model-0: 6055it [00:09, 1154.60it/s]
# Running Model-0: 6175it [00:09, 1096.87it/s]
# Running Model-0: 6288it [00:09, 1100.01it/s]
# Running Model-0: 6401it [00:09, 984.80it/s]
# Running Model-0: 6503it [00:09, 827.66it/s]
# Running Model-0: 6592it [00:09, 723.62it/s]
# Running Model-0: 6670it [00:10, 716.28it/s]
# Running Model-0: 6746it [00:10, 570.19it/s]
# Running Model-0: 6823it [00:10, 611.56it/s]
# Running Model-0: 6891it [00:10, 601.21it/s]
# Running Model-0: 7037it [00:10, 807.40it/s]
# Running Model-0: 7153it [00:10, 896.58it/s]
# Running Model-0: 7250it [00:10, 892.26it/s]
# Running Model-0: 7379it [00:10, 999.78it/s]
# Running Model-0: 7504it [00:10, 1069.48it/s]
# Running Model-0: 7622it [00:11, 1100.68it/s]
# Running Model-0: 7746it [00:11, 1139.14it/s]
# Running Model-0: 7862it [00:11, 951.58it/s]
# Running Model-0: 7964it [00:11, 853.64it/s]
# Running Model-0: 8056it [00:11, 779.08it/s]
# Running Model-0: 8141it [00:11, 795.80it/s]
# Running Model-0: 8225it [00:11, 772.40it/s]
# Running Model-0: 8305it [00:11, 719.10it/s]
# Running Model-0: 8406it [00:12, 789.69it/s]
# Running Model-0: 8488it [00:12, 770.11it/s]
# Running Model-0: 8567it [00:12, 641.73it/s]
# Running Model-0: 8636it [00:12, 645.88it/s]
# Running Model-0: 8778it [00:12, 841.83it/s]
# Running Model-0: 8870it [00:12, 862.56it/s]
# Running Model-0: 8962it [00:12, 876.49it/s]
# Running Model-0: 9053it [00:12, 854.50it/s]
# Running Model-0: 9141it [00:13, 709.93it/s]
# Running Model-0: 9218it [00:13, 711.99it/s]
# Running Model-0: 9354it [00:13, 877.64it/s]
# Running Model-0: 9448it [00:13, 824.93it/s]
# Running Model-0: 9535it [00:13, 811.03it/s]
# Running Model-0: 9619it [00:13, 705.04it/s]
# Running Model-0: 9694it [00:13, 639.24it/s]
# Running Model-0: 9762it [00:13, 642.16it/s]
# Running Model-0: 9867it [00:14, 743.74it/s]
# Running Model-0: 9945it [00:14, 685.25it/s]
# Running Model-0: 10017it [00:14, 632.67it/s]
# Running Model-0: 10083it [00:14, 609.46it/s]
# Running Model-0: 10174it [00:14, 685.20it/s]
# Running Model-0: 10245it [00:14, 660.01it/s]
# Running Model-0: 10313it [00:14, 615.55it/s]
# Running Model-0: 10377it [00:15, 472.88it/s]
# Running Model-0: 10430it [00:15, 438.67it/s]
# Running Model-0: 10478it [00:15, 439.83it/s]
# Running Model-0: 10525it [00:15, 446.93it/s]
# Running Model-0: 10572it [00:15, 402.48it/s]
# Running Model-0: 10627it [00:15, 437.61it/s]
# Running Model-0: 10673it [00:15, 319.95it/s]
# Running Model-0: 10711it [00:15, 321.25it/s]
# Running Model-0: 10797it [00:16, 442.13it/s]
# Running Model-0: 10849it [00:16, 426.68it/s]
# Running Model-0: 10897it [00:16, 428.64it/s]
# Running Model-0: 10957it [00:16, 471.40it/s]
# Running Model-0: 11020it [00:16, 510.30it/s]
# Running Model-0: 11102it [00:16, 594.66it/s]
# Running Model-0: 11165it [00:16, 545.71it/s]
# Running Model-0: 11223it [00:16, 512.50it/s]
# Running Model-0: 11277it [00:17, 518.72it/s]
# Running Model-0: 11331it [00:17, 391.36it/s]
# Running Model-0: 11383it [00:17, 408.79it/s]
# Running Model-0: 11429it [00:17, 400.21it/s]
# Running Model-0: 11483it [00:17, 431.08it/s]
# Running Model-0: 11529it [00:17, 340.79it/s]
# Running Model-0: 11573it [00:17, 362.62it/s]
# Running Model-0: 11626it [00:17, 399.34it/s]
# Running Model-0: 11692it [00:18, 459.11it/s]
# Running Model-0: 11742it [00:18, 399.99it/s]
# Running Model-0: 11786it [00:18, 387.37it/s]
# Running Model-0: 11828it [00:18, 326.76it/s]
# Running Model-0: 11886it [00:18, 383.07it/s]
# Running Model-0: 11948it [00:18, 440.56it/s]
# Running Model-0: 12015it [00:18, 497.34it/s]
# Running Model-0: 12069it [00:19, 419.29it/s]
# Running Model-0: 12140it [00:19, 488.57it/s]
# Running Model-0: 12194it [00:19, 484.02it/s]
# Running Model-0: 12256it [00:19, 508.21it/s]
# Running Model-0: 12341it [00:19, 598.99it/s]
# Running Model-0: 12440it [00:19, 706.63it/s]
# Running Model-0: 12514it [00:19, 649.10it/s]
# Running Model-0: 12582it [00:19, 616.99it/s]
# Running Model-0: 12646it [00:19, 581.40it/s]
# Running Model-0: 12706it [00:20, 554.71it/s]
# Running Model-0: 12763it [00:20, 538.88it/s]
# Running Model-0: 12823it [00:20, 553.73it/s]
# Running Model-0: 12880it [00:20, 522.75it/s]
# Running Model-0: 12941it [00:20, 545.28it/s]
# Running Model-0: 12997it [00:20, 481.04it/s]
# Running Model-0: 13055it [00:20, 498.65it/s]
# Running Model-0: 13107it [00:20, 461.54it/s]
# Running Model-0: 13163it [00:21, 485.67it/s]
# Running Model-0: 13213it [00:21, 460.11it/s]
# Running Model-0: 13261it [00:21, 379.74it/s]
# Running Model-0: 13302it [00:21, 367.25it/s]
# Running Model-0: 13351it [00:21, 396.53it/s]
# Running Model-0: 13413it [00:21, 453.44it/s]
# Running Model-0: 13469it [00:21, 480.17it/s]
# Running Model-0: 13519it [00:21, 478.47it/s]
# Running Model-0: 13569it [00:21, 459.96it/s]
# Running Model-0: 13617it [00:22, 441.42it/s]
# Running Model-0: 13713it [00:22, 577.07it/s]
# Running Model-0: 13773it [00:22, 554.81it/s]
# Running Model-0: 13851it [00:22, 615.51it/s]
# Running Model-0: 13914it [00:22, 566.14it/s]
# Running Model-0: 13973it [00:22, 456.91it/s]
# Running Model-0: 14023it [00:22, 405.81it/s]
# Running Model-0: 14103it [00:23, 493.63it/s]
# Running Model-0: 14160it [00:23, 511.20it/s]
# Running Model-0: 14216it [00:23, 484.11it/s]
# Running Model-0: 14268it [00:23, 448.16it/s]
# Running Model-0: 14316it [00:23, 443.39it/s]
# Running Model-0: 14371it [00:23, 470.66it/s]
# Running Model-0: 14458it [00:23, 576.69it/s]
# Running Model-0: 14539it [00:23, 637.41it/s]
# Running Model-0: 14651it [00:23, 772.70it/s]
# Running Model-0: 14738it [00:23, 784.40it/s]
# Running Model-0: 14819it [00:24, 654.86it/s]
# Running Model-0: 14930it [00:24, 769.28it/s]
# Running Model-0: 15013it [00:24, 651.78it/s]
# Running Model-0: 15086it [00:24, 669.51it/s]
# Running Model-0: 15160it [00:24, 687.06it/s]
# Running Model-0: 15252it [00:24, 747.79it/s]
# Running Model-0: 15331it [00:24, 711.94it/s]
# Running Model-0: 15405it [00:25, 667.38it/s]
# Running Model-0: 15487it [00:25, 707.05it/s]
# Running Model-0: 15577it [00:25, 758.50it/s]
# Running Model-0: 15670it [00:25, 805.17it/s]
# Running Model-0: 15765it [00:25, 842.78it/s]
# Running Model-0: 15851it [00:25, 741.69it/s]
# Running Model-0: 15929it [00:25, 682.91it/s]
# Running Model-0: 16032it [00:25, 770.67it/s]
# Running Model-0: 16150it [00:25, 878.42it/s]
# Running Model-0: 16242it [00:26, 748.53it/s]
# Running Model-0: 16323it [00:26, 671.10it/s]
# Running Model-0: 16395it [00:26, 638.51it/s]
# Running Model-0: 16463it [00:26, 522.37it/s]
# Running Model-0: 16521it [00:26, 530.89it/s]
# Running Model-0: 16651it [00:26, 709.34it/s]
# Running Model-0: 16737it [00:26, 747.08it/s]
# Running Model-0: 16818it [00:27, 652.31it/s]
# Running Model-0: 16890it [00:27, 655.50it/s]
# Running Model-0: 16965it [00:27, 678.41it/s]
# Running Model-0: 17042it [00:27, 701.42it/s]
# Running Model-0: 17115it [00:27, 613.27it/s]
# Running Model-0: 17180it [00:27, 564.20it/s]
# Running Model-0: 17240it [00:27, 503.41it/s]
# Running Model-0: 17301it [00:27, 528.37it/s]
# Running Model-0: 17357it [00:28, 512.34it/s]
# Running Model-0: 17410it [00:28, 507.67it/s]
# Running Model-0: 17462it [00:28, 497.85it/s]
# Running Model-0: 17574it [00:28, 638.45it/s]
# Running Model-0: 17639it [00:28, 596.44it/s]
# Running Model-0: 17700it [00:28, 534.05it/s]
# Running Model-0: 17755it [00:28, 524.86it/s]
# Running Model-0: 17820it [00:28, 556.27it/s]
# Running Model-0: 17877it [00:28, 551.66it/s]
# Running Model-0: 17933it [00:29, 533.34it/s]
# Running Model-0: 18023it [00:29, 633.36it/s]
# Running Model-0: 18101it [00:29, 669.94it/s]
# Running Model-0: 18170it [00:29, 568.39it/s]
# Running Model-0: 18242it [00:29, 596.70it/s]
# Running Model-0: 18305it [00:29, 600.17it/s]
# Running Model-0: 18395it [00:29, 680.14it/s]
# Running Model-0: 18466it [00:29, 687.43it/s]
# Running Model-0: 18537it [00:29, 566.07it/s]
# Running Model-0: 18599it [00:30, 482.68it/s]
# Running Model-0: 18727it [00:30, 653.43it/s]
# Running Model-0: 18806it [00:30, 680.33it/s]
# Running Model-0: 18880it [00:30, 600.18it/s]
# Running Model-0: 18952it [00:30, 623.45it/s]
# Running Model-0: 19019it [00:30, 598.75it/s]
# Running Model-0: 19082it [00:31, 491.06it/s]
# Running Model-0: 19136it [00:31, 426.05it/s]
# Running Model-0: 19183it [00:31, 408.09it/s]
# Running Model-0: 19227it [00:31, 392.67it/s]
# Running Model-0: 19268it [00:31, 395.01it/s]
# Running Model-0: 19309it [00:31, 366.64it/s]
# Running Model-0: 19347it [00:31, 364.95it/s]
# Running Model-0: 19396it [00:31, 390.79it/s]
# Running Model-0: 19436it [00:31, 368.39it/s]
# Running Model-0: 19474it [00:32, 366.60it/s]
# Running Model-0: 19514it [00:32, 374.00it/s]
# Running Model-0: 19552it [00:32, 354.91it/s]
# Running Model-0: 19596it [00:32, 374.09it/s]
# Running Model-0: 19661it [00:32, 450.05it/s]
# Running Model-0: 19707it [00:32, 430.52it/s]
# Running Model-0: 19751it [00:32, 409.64it/s]
# Running Model-0: 19793it [00:32, 401.18it/s]
# Running Model-0: 19834it [00:32, 399.45it/s]
# Running Model-0: 19878it [00:33, 406.48it/s]
# Running Model-0: 19919it [00:33, 396.64it/s]
# Running Model-0: 19967it [00:33, 420.05it/s]
# Running Model-0: 20069it [00:33, 590.61it/s]
# Running Model-0: 20167it [00:33, 702.95it/s]
# Running Model-0: 20239it [00:33, 585.65it/s]
# Running Model-0: 20302it [00:33, 557.98it/s]
# Running Model-0: 20368it [00:33, 582.74it/s]
# Running Model-0: 20429it [00:34, 478.51it/s]
# Running Model-0: 20482it [00:34, 434.75it/s]
# Running Model-0: 20551it [00:34, 492.36it/s]
# Running Model-0: 20647it [00:34, 607.51it/s]
# Running Model-0: 20740it [00:34, 690.14it/s]
# Running Model-0: 20837it [00:34, 763.95it/s]
# Running Model-0: 20931it [00:34, 812.52it/s]
# Running Model-0: 21045it [00:34, 904.39it/s]
# Running Model-0: 21139it [00:34, 848.10it/s]
# Running Model-0: 21227it [00:35, 802.41it/s]
# Running Model-0: 21310it [00:35, 747.28it/s]
# Running Model-0: 21387it [00:35, 688.51it/s]
# Running Model-0: 21458it [00:35, 557.61it/s]
# Running Model-0: 21519it [00:35, 507.81it/s]
# Running Model-0: 21575it [00:35, 518.95it/s]
# Running Model-0: 21630it [00:36, 422.99it/s]
# Running Model-0: 21677it [00:36, 343.71it/s]
# Running Model-0: 21716it [00:36, 318.43it/s]
# Running Model-0: 21751it [00:36, 300.66it/s]
# Running Model-0: 21814it [00:36, 366.18it/s]
# Running Model-0: 21901it [00:36, 481.45it/s]
# Running Model-0: 22005it [00:36, 617.87it/s]
# Running Model-0: 22074it [00:36, 556.14it/s]
# Running Model-0: 22159it [00:37, 603.44it/s]
# Running Model-0: 22224it [00:37, 558.41it/s]
# Running Model-0: 22289it [00:37, 580.66it/s]
# Running Model-0: 22350it [00:37, 583.45it/s]
# Running Model-0: 22430it [00:37, 639.15it/s]
# Running Model-0: 22496it [00:37, 642.34it/s]
# Running Model-0: 22562it [00:37, 615.61it/s]
# Running Model-0: 22625it [00:37, 487.52it/s]
# Running Model-0: 22679it [00:38, 414.45it/s]
# Running Model-0: 22726it [00:38, 390.51it/s]
# Running Model-0: 22818it [00:38, 498.39it/s]
# Running Model-0: 22873it [00:38, 388.53it/s]
# Running Model-0: 22938it [00:38, 441.76it/s]
# Running Model-0: 23067it [00:38, 633.48it/s]
# Running Model-0: 23142it [00:38, 600.90it/s]
# Running Model-0: 23266it [00:39, 752.13it/s]
# Running Model-0: 23351it [00:39, 710.98it/s]
# Running Model-0: 23429it [00:39, 621.81it/s]
# Running Model-0: 23498it [00:39, 571.22it/s]
# Running Model-0: 23560it [00:39, 516.59it/s]
# Running Model-0: 23626it [00:39, 545.79it/s]
# Running Model-0: 23684it [00:40, 419.18it/s]
# Running Model-0: 23732it [00:40, 423.32it/s]
# Running Model-0: 23810it [00:40, 502.73it/s]
# Running Model-0: 23887it [00:40, 566.80it/s]
# Running Model-0: 23950it [00:40, 447.37it/s]
# Running Model-0: 24003it [00:40, 390.53it/s]
# Running Model-0: 24048it [00:40, 344.37it/s]
# Running Model-0: 24100it [00:41, 378.78it/s]
# Running Model-0: 24143it [00:41, 378.97it/s]
# Running Model-0: 24185it [00:41, 327.87it/s]
# Running Model-0: 24221it [00:41, 331.10it/s]
# Running Model-0: 24285it [00:41, 403.41it/s]
# Running Model-0: 24329it [00:41, 396.69it/s]
# Running Model-0: 24371it [00:41, 330.13it/s]
# Running Model-0: 24408it [00:41, 335.06it/s]
# Running Model-0: 24444it [00:42, 310.78it/s]
# Running Model-0: 24483it [00:42, 314.06it/s]
# Running Model-0: 24539it [00:42, 374.91it/s]
# Running Model-0: 24579it [00:42, 375.75it/s]
# Running Model-0: 24619it [00:42, 369.58it/s]
# Running Model-0: 24674it [00:42, 418.28it/s]
# Running Model-0: 24718it [00:42, 321.93it/s]
# Running Model-0: 24755it [00:43, 291.59it/s]
# Running Model-0: 24788it [00:43, 269.64it/s]
# Running Model-0: 24818it [00:43, 239.89it/s]
# Running Model-0: 24849it [00:43, 253.95it/s]
# Running Model-0: 24917it [00:43, 353.51it/s]
# Running Model-0: 24957it [00:43, 332.12it/s]
# Running Model-0: 24994it [00:43, 293.32it/s]
# Running Model-0: 25043it [00:43, 336.06it/s]
# Running Model-0: 25080it [00:44, 327.88it/s]
# Running Model-0: 25115it [00:44, 261.01it/s]
# Running Model-0: 25147it [00:44, 270.70it/s]
# Running Model-0: 25177it [00:44, 271.02it/s]
# Running Model-0: 25206it [00:44, 256.35it/s]
# Running Model-0: 25276it [00:44, 365.01it/s]
# Running Model-0: 25316it [00:44, 293.49it/s]
# Running Model-0: 25350it [00:45, 262.95it/s]
# Running Model-0: 25391it [00:45, 294.44it/s]
# Running Model-0: 25433it [00:45, 321.73it/s]
# Running Model-0: 25469it [00:45, 317.23it/s]
# Running Model-0: 25517it [00:45, 357.25it/s]
# Running Model-0: 25555it [00:45, 323.87it/s]
# Running Model-0: 25605it [00:45, 361.76it/s]
# Running Model-0: 25643it [00:45, 361.97it/s]
# Running Model-0: 25707it [00:45, 436.31it/s]
# Running Model-0: 25789it [00:46, 542.45it/s]
# Running Model-0: 25846it [00:46, 515.49it/s]
# Running Model-0: 25900it [00:46, 438.72it/s]
# Running Model-0: 25947it [00:46, 408.00it/s]
# Running Model-0: 25990it [00:46, 387.42it/s]
# Running Model-0: 26091it [00:46, 540.58it/s]
# Running Model-0: 26150it [00:46, 532.45it/s]
# Running Model-0: 26211it [00:46, 546.88it/s]
# Running Model-0: 26268it [00:47, 464.87it/s]
# Running Model-0: 26318it [00:47, 407.18it/s]
# Running Model-0: 26402it [00:47, 505.71it/s]
# Running Model-0: 26458it [00:47, 494.50it/s]
# Running Model-0: 26511it [00:47, 500.87it/s]
# Running Model-0: 26564it [00:47, 496.52it/s]
# Running Model-0: 26655it [00:47, 605.81it/s]
# Running Model-0: 26765it [00:47, 737.29it/s]
# Running Model-0: 26852it [00:47, 766.01it/s]
# Running Model-0: 26931it [00:48, 721.93it/s]
# Running Model-0: 27005it [00:48, 582.18it/s]
# Running Model-0: 27069it [00:48, 460.60it/s]
# Running Model-0: 27122it [00:48, 430.82it/s]
# Running Model-0: 27170it [00:48, 393.22it/s]
# Running Model-0: 27219it [00:48, 413.71it/s]
# Running Model-0: 27264it [00:49, 360.14it/s]
# Running Model-0: 27303it [00:49, 314.54it/s]
# Running Model-0: 27337it [00:49, 310.71it/s]
# Running Model-0: 27370it [00:49, 293.52it/s]
# Running Model-0: 27421it [00:49, 332.93it/s]
# Running Model-0: 27456it [00:49, 314.83it/s]
# Running Model-0: 27491it [00:49, 313.21it/s]
# Running Model-0: 27525it [00:49, 315.38it/s]
# Running Model-0: 27559it [00:50, 306.79it/s]
# Running Model-0: 27614it [00:50, 370.74it/s]
# Running Model-0: 27719it [00:50, 555.87it/s]
# Running Model-0: 27778it [00:50, 547.92it/s]
# Running Model-0: 27835it [00:50, 542.90it/s]
# Running Model-0: 27891it [00:50, 469.54it/s]
# Running Model-0: 27967it [00:50, 543.53it/s]
# Running Model-0: 28026it [00:50, 555.51it/s]
# Running Model-0: 28166it [00:50, 788.90it/s]
# Running Model-0: 28249it [00:51, 636.83it/s]
# Running Model-0: 28320it [00:51, 611.46it/s]
# Running Model-0: 28387it [00:51, 580.53it/s]
# Running Model-0: 28546it [00:51, 827.57it/s]
# Running Model-0: 28659it [00:51, 905.49it/s]
# Running Model-0: 28757it [00:51, 887.92it/s]
# Running Model-0: 28851it [00:51, 840.85it/s]
# Running Model-0: 28939it [00:52, 743.47it/s]
# Running Model-0: 29027it [00:52, 776.86it/s]
# Running Model-0: 29146it [00:52, 883.58it/s]
# Running Model-0: 29239it [00:52, 884.62it/s]
# Running Model-0: 29331it [00:52, 885.53it/s]
# Running Model-0: 29422it [00:52, 719.76it/s]
# Running Model-0: 29501it [00:52, 639.72it/s]
# Running Model-0: 29594it [00:52, 696.88it/s]
# Running Model-0: 29695it [00:53, 773.87it/s]
# Running Model-0: 29780it [00:53, 793.12it/s]
# Running Model-0: 29949it [00:53, 1035.06it/s]
# Running Model-0: 30058it [00:53, 895.45it/s]
# Running Model-0: 30155it [00:53, 789.00it/s]
# Running Model-0: 30247it [00:53, 819.93it/s]
# Running Model-0: 30379it [00:53, 946.57it/s]
# Running Model-0: 30480it [00:53, 936.16it/s]
# Running Model-0: 30578it [00:53, 940.16it/s]
# Running Model-0: 30675it [00:54, 816.70it/s]
# Running Model-0: 30762it [00:54, 791.17it/s]
# Running Model-0: 30845it [00:54, 683.00it/s]
# Running Model-0: 30918it [00:54, 670.99it/s]
# Running Model-0: 31000it [00:54, 702.50it/s]
# Running Model-0: 31073it [00:54, 677.81it/s]
# Running Model-0: 31187it [00:54, 797.52it/s]
# Running Model-0: 31272it [00:54, 809.44it/s]
# Running Model-0: 31385it [00:55, 897.53it/s]
# Running Model-0: 31489it [00:55, 936.94it/s]
# Running Model-0: 31677it [00:55, 1209.10it/s]
# Running Model-0: 31840it [00:55, 1328.34it/s]
# Running Model-0: 31975it [00:55, 1296.08it/s]
# Running Model-0: 32107it [00:55, 971.64it/s]
# Running Model-0: 32217it [00:55, 844.07it/s]
# Running Model-0: 32313it [00:55, 838.69it/s]
# Running Model-0: 32405it [00:56, 847.94it/s]
# Running Model-0: 32552it [00:56, 1001.02it/s]
# Running Model-0: 32729it [00:56, 1191.26it/s]
# Running Model-0: 32856it [00:56, 1179.78it/s]
# Running Model-0: 33012it [00:56, 1282.49it/s]
# Running Model-0: 33145it [00:56, 1278.21it/s]
# Running Model-0: 33276it [00:56, 1124.99it/s]
# Running Model-0: 33394it [00:56, 831.30it/s]
# Running Model-0: 33492it [00:57, 746.52it/s]
# Running Model-0: 33577it [00:57, 740.58it/s]
# Running Model-0: 33659it [00:57, 744.71it/s]
# Running Model-0: 33768it [00:57, 827.08it/s]
# Running Model-0: 33913it [00:57, 985.16it/s]
# Running Model-0: 34039it [00:57, 1056.80it/s]
# Running Model-0: 34176it [00:57, 1141.71it/s]
# Running Model-0: 34312it [00:57, 1203.14it/s]
# Running Model-0: 34477it [00:57, 1330.03it/s]
# Running Model-0: 34614it [00:58, 1331.33it/s]
# Running Model-0: 34750it [00:58, 1091.28it/s]
# Running Model-0: 34868it [00:58, 956.31it/s]
# Running Model-0: 34972it [00:58, 808.00it/s]
# Running Model-0: 35090it [00:58, 888.80it/s]
# Running Model-0: 35193it [00:58, 922.38it/s]
# Running Model-0: 35293it [00:58, 934.84it/s]
# Running Model-0: 35392it [00:59, 856.82it/s]
# Running Model-0: 35516it [00:59, 953.96it/s]
# Running Model-0: 35678it [00:59, 1131.32it/s]
# Running Model-0: 35816it [00:59, 1197.62it/s]
# Running Model-0: 36000it [00:59, 1377.62it/s]
# Running Model-0: 36153it [00:59, 1419.66it/s]
# Running Model-0: 36299it [00:59, 1264.75it/s]
# Running Model-0: 36431it [00:59, 1140.06it/s]
# Running Model-0: 36573it [00:59, 1209.78it/s]
# Running Model-0: 36699it [01:00, 1015.46it/s]
# Running Model-0: 36809it [01:00, 802.57it/s]
# Running Model-0: 36901it [01:00, 753.26it/s]
# Running Model-0: 37042it [01:00, 890.06it/s]
# Running Model-0: 37142it [01:00, 892.83it/s]
# Running Model-0: 37270it [01:00, 987.59it/s]
# Running Model-0: 37396it [01:00, 1057.73it/s]
# Running Model-0: 37529it [01:01, 1130.36it/s]
# Running Model-0: 37648it [01:01, 1059.09it/s]
# Running Model-0: 37759it [01:01, 1021.53it/s]
# Running Model-0: 37931it [01:01, 1208.35it/s]
# Running Model-0: 38098it [01:01, 1333.95it/s]
# Running Model-0: 38236it [01:01, 1130.02it/s]
# Running Model-0: 38357it [01:01, 881.68it/s]
# Running Model-0: 38459it [01:02, 776.83it/s]
# Running Model-0: 38547it [01:02, 784.95it/s]
# Running Model-0: 38739it [01:02, 1042.05it/s]
# Running Model-0: 38861it [01:02, 1084.18it/s]
# Running Model-0: 39007it [01:02, 1181.35it/s]
# Running Model-0: 39164it [01:02, 1285.37it/s]
# Running Model-0: 39300it [01:02, 1075.99it/s]
# Running Model-0: 39419it [01:02, 1033.09it/s]
# Running Model-0: 39530it [01:02, 1048.85it/s]
# Running Model-0: 39641it [01:03, 972.52it/s]
# Running Model-0: 39754it [01:03, 996.58it/s]
# Running Model-0: 39858it [01:03, 863.54it/s]
# Running Model-0: 39950it [01:03, 746.60it/s]
# Running Model-0: 40079it [01:03, 870.28it/s]
# Running Model-0: 40194it [01:03, 937.49it/s]
# Running Model-0: 40297it [01:03, 958.87it/s]
# Running Model-0: 40398it [01:03, 874.17it/s]
# Running Model-0: 40490it [01:04, 871.10it/s]
# Running Model-0: 40639it [01:04, 1033.89it/s]
# Running Model-0: 40747it [01:04, 932.62it/s]
# Running Model-0: 40845it [01:04, 899.16it/s]
# Running Model-0: 40939it [01:04, 705.24it/s]
# Running Model-0: 41018it [01:04, 643.18it/s]
# Running Model-0: 41089it [01:04, 616.97it/s]
# Running Model-0: 41155it [01:05, 557.55it/s]
# Running Model-0: 41219it [01:05, 550.72it/s]
# Running Model-0: 41293it [01:05, 593.93it/s]
# Running Model-0: 41355it [01:05, 577.40it/s]
# Running Model-0: 41452it [01:05, 677.13it/s]
# Running Model-0: 41604it [01:05, 901.92it/s]
# Running Model-0: 41699it [01:05, 894.33it/s]
# Running Model-0: 41801it [01:05, 928.03it/s]
# Running Model-0: 41897it [01:06, 759.40it/s]
# Running Model-0: 41980it [01:06, 674.54it/s]
# Running Model-0: 42054it [01:06, 544.01it/s]
# Running Model-0: 42116it [01:06, 472.56it/s]
# Running Model-0: 42169it [01:06, 430.35it/s]
# Running Model-0: 42216it [01:06, 396.47it/s]
# Running Model-0: 42300it [01:06, 488.71it/s]
# Running Model-0: 42355it [01:07, 441.64it/s]
# Running Model-0: 42404it [01:07, 428.32it/s]
# Running Model-0: 42450it [01:07, 434.95it/s]
# Running Model-0: 42537it [01:07, 542.78it/s]
# Running Model-0: 42596it [01:07, 484.87it/s]
# Running Model-0: 42671it [01:07, 550.16it/s]
# Running Model-0: 42772it [01:07, 669.02it/s]
# Running Model-0: 42844it [01:07, 602.97it/s]
# Running Model-0: 42909it [01:08, 582.82it/s]
# Running Model-0: 42971it [01:08, 550.87it/s]
# Running Model-0: 43029it [01:08, 547.09it/s]
# Running Model-0: 43086it [01:08, 472.13it/s]
# Running Model-0: 43136it [01:08, 433.70it/s]
# Running Model-0: 43182it [01:08, 408.28it/s]
# Running Model-0: 43228it [01:08, 420.52it/s]
# Running Model-0: 43272it [01:09, 339.94it/s]
# Running Model-0: 43315it [01:09, 360.21it/s]
# Running Model-0: 43354it [01:09, 292.38it/s]
# Running Model-0: 43390it [01:09, 305.21it/s]
# Running Model-0: 43451it [01:09, 375.51it/s]
# Running Model-0: 43493it [01:09, 339.94it/s]
# Running Model-0: 43531it [01:09, 309.66it/s]
# Running Model-0: 43597it [01:09, 390.45it/s]
# Running Model-0: 43773it [01:10, 730.99it/s]
# Running Model-0: 43862it [01:10, 771.86it/s]
# Running Model-0: 43947it [01:10, 544.86it/s]
# Running Model-0: 44018it [01:10, 577.96it/s]
# Running Model-0: 44088it [01:10, 599.21it/s]
# Running Model-0: 44157it [01:10, 573.56it/s]
# Running Model-0: 44229it [01:10, 606.28it/s]
# Running Model-0: 44295it [01:11, 597.22it/s]
# Running Model-0: 44359it [01:11, 604.74it/s]
# Running Model-0: 44424it [01:11, 616.57it/s]
# Running Model-0: 44488it [01:11, 606.37it/s]
# Running Model-0: 44611it [01:11, 778.19it/s]
# Running Model-0: 44695it [01:11, 794.75it/s]
# Running Model-0: 44776it [01:11, 715.34it/s]
# Running Model-0: 44850it [01:11, 692.51it/s]
# Running Model-0: 44921it [01:11, 653.63it/s]
# Running Model-0: 44999it [01:12, 624.48it/s]
# Running Model-0: 100%|████████████████████████████| 1/1 [01:12<00:00, 72.26s/it]
# Fitting node Ridge-0...

# %% [markdown]
# Let's visualize the coefficients learned by the model:

# %%
lin = ["$x_t$", "$y_t$", "$z_t$", "$x_{t-1}$", "$y_{t-1}$", "$z_{t-1}$", "$x_{t-2}$", "$y_{t-2}$", "$z_{t-2}$"]

nonlin = []
for idx in nvar._monomial_idx:
    idx = idx.astype(int)
    if idx[0] == idx[1]:
        c = lin[idx[0]][:-1] + "^2$"
    else:
        c = " ".join((lin[idx[0]][:-1], lin[idx[1]][1:]))

    nonlin.append(c)

coefs = ["$c$"] + lin + nonlin

# %%
fig = plt.figure(figsize=(10, 10))

Wout = np.r_[readout.bias, readout.Wout]
x_Wout, y_Wout, z_Wout = Wout[:, 0], Wout[:, 1], Wout[:, 2]

ax = fig.add_subplot(131)
ax.set_xlim(-0.2, 0.2)
ax.grid(axis="y")
ax.set_xlabel("$[W_{out}]_x$")
ax.set_ylabel("Features")
ax.set_yticks(np.arange(len(coefs)))
ax.set_yticklabels(coefs[::-1])
ax.barh(np.arange(x_Wout.size), x_Wout.ravel()[::-1])

ax1 = fig.add_subplot(132)
ax1.set_xlim(-0.2, 0.2)
ax1.grid(axis="y")
ax1.set_yticks(np.arange(len(coefs)))
ax1.set_xlabel("$[W_{out}]_y$")
ax1.barh(np.arange(y_Wout.size), y_Wout.ravel()[::-1])

ax2 = fig.add_subplot(133)
ax2.set_xlim(-0.2, 0.2)
ax2.grid(axis="y")
ax2.set_yticks(np.arange(len(coefs)))
ax2.set_xlabel("$[W_{out}]_z$")
ax2.barh(np.arange(z_Wout.size), z_Wout.ravel()[::-1])

plt.show()

# %% [markdown]
# Now, let's perform one-step-ahead prediction:

# %%
nvar.run(X[train_steps:warm_steps+train_steps]) # warming phase

u = X[warm_steps+train_steps]
Y_pred = np.zeros((test_steps, readout.output_dim))
for i in range(test_steps):
    Y_pred[i, :] = model(u)
    u = Y_pred[i, :]
# Out:
# Running NVAR-0: 100%|███████████████████| 25000/25000 [00:08<00:00, 2898.04it/s]

# %%
Y_test = X[warm_steps+train_steps:]

fig = plt.figure(figsize=(20, 10))
ax  = fig.add_subplot(121, projection='3d')
ax.set_title("Generated attractor")
ax.set_xlabel("$x$")
ax.set_ylabel("$y$")
ax.set_zlabel("$z$")
ax.grid(False)
ax.plot(Y_pred[:, 0], Y_pred[:, 1], Y_pred[:, 2], color='red', lw=.3)

ax2 = fig.add_subplot(122, projection='3d')
ax2.set_title("Real attractor")
ax2.grid(False)
ax2.plot(Y_test[:, 0], Y_test[:, 1], Y_test[:, 2], lw=.3)

plt.show()

# %% [markdown]
# ## 2. Lobe prediction

# %% [markdown]
# ### 2.1 Definition of reconstructing functions

# %%
def general_reconstruction(X, train_steps, warm_steps, n_leaps, leap_len, delay, order, strides, ridge, verb):
    
    shift = n_leaps*leap_len
    nvar    = NVAR(delay=delay, order=order, strides=strides)
    readout = Ridge(output_dim=1, ridge=ridge)
    model = nvar >> readout
    
    X_train = X[:train_steps+warm_steps-leap_len, 0]
    X_train = X_train.reshape(-1,1) # x coordinate
    Y_train = X[leap_len:train_steps+warm_steps, 0].reshape(-1,1)  # z coordinate
    model = model.fit(X_train, Y_train, warmup=warm_steps)
    nvar.run(X[train_steps:warm_steps+train_steps, 0].reshape(-1,1)) # warming phase
    
    X_test = X[warm_steps+train_steps:-shift, 0]
    X_test = X_test.reshape(-1,1) # x coordinate
    Y_test = X[warm_steps+train_steps+shift:, 0].reshape(-1,1)
    iterative_prediction = X_test
    
    for i in range(n_leaps):
        iterative_prediction = model.run(iterative_prediction)
        if verb:
            print(str(i+1)+"th/"+str(n_leaps)+" prediction step performed")
    Y_pred = iterative_prediction
    
    Y_differences = np.abs(Y_pred-Y_test)
    
    return(Y_pred, Y_test, Y_differences, shift, readout)


def smoother(sign_vec, window, tolerance):
    
    new_sign_vec = sign_vec.copy()
    
    for i in range(window, len(sign_vec)-window):
        if np.count_nonzero(sign_vec[i-window:i+window]*sign_vec[i] < 0) > 2*tolerance*window:
            new_sign_vec[i] = - sign_vec[i]
            
    return(new_sign_vec)


def analizer(triggers_real, triggers_pred_smoothed, ranger):
    
    triggers_wrong = triggers_pred_smoothed.copy()
    
    for i in range(ranger, len(triggers_real)-ranger):
        if triggers_real[i] > 0.5:
            if np.count_nonzero(triggers_pred_smoothed[i-ranger: i+ranger] > 0.5) > 0.5:
                triggers_wrong[i-ranger: i+ranger] = 0 * triggers_real[i-ranger: i+ranger]
            else:
                triggers_wrong[i-ranger: i+ranger] = -1 * triggers_real[i-ranger: i+ranger]
                #print(i)
                
    return(triggers_wrong)


def grouper(triggers_wrong, groupsize):
    
    triggers_wrong_grouped = triggers_wrong.copy()
    state = 0
    
    for i in range(groupsize, len(triggers_wrong)-groupsize):
        if state == 1 and np.count_nonzero(triggers_wrong[i-groupsize:i+groupsize] > 0.5) > 1:
            triggers_wrong_grouped[i-groupsize:i+groupsize] = 0 * triggers_wrong[i-groupsize:i+groupsize]
            triggers_wrong_grouped[i] = 1
            state = 0
        if np.count_nonzero(triggers_wrong[i-groupsize:i+groupsize] > 0.5) < 1:
            state = 1
            
    return(triggers_wrong_grouped)


def accuracy_detector(Y_pred, Y_test, window, tolerance, ranger, groupsize):
    
    Y_test_sign = np.sign(Y_test)
    Y_pred_sign = np.sign(Y_pred)
    Y_differences_sign = np.abs(Y_pred_sign-Y_test_sign)/2
    Y_pred_sign_smoothed = smoother(Y_pred_sign, window, tolerance)
    Y_differences_sign_smoothed = np.abs(Y_pred_sign_smoothed-Y_test_sign)/2
    
    error_level = np.sum(Y_differences_sign)/len(Y_differences_sign)
    error_level_smoothed = np.sum(Y_differences_sign_smoothed)/len(Y_differences_sign_smoothed)

    triggers_real = np.abs(Y_test_sign[1:]-Y_test_sign[:-1])/2
    #print(triggers_real)
    #triggers_pred = np.abs(Y_pred_sign[1:]-Y_pred_sign[:-1])
    triggers_pred_smoothed = np.abs(Y_pred_sign_smoothed[1:]-Y_pred_sign_smoothed[:-1])/2
    
    triggers_wrong = analizer(triggers_real, triggers_pred_smoothed, ranger)
    triggers_wrong = grouper(triggers_wrong, groupsize)
    
    true_positive = np.count_nonzero(triggers_real > 0.5)
    false_positive = np.count_nonzero(triggers_wrong > 0.5)
    false_negative = np.count_nonzero(triggers_wrong < -0.5)
    total_triggers = true_positive + false_positive
    
    true_positive_rate = true_positive/total_triggers
    false_positive_rate = false_positive/total_triggers
    false_negative_rate = false_negative/total_triggers
    
    return(Y_test_sign, Y_pred_sign, Y_differences_sign,
           Y_pred_sign_smoothed, Y_differences_sign_smoothed,
           triggers_real, triggers_pred_smoothed, triggers_wrong,
           true_positive_rate, false_positive_rate, false_negative_rate)


def general_comparer(Y_pred, Y_test, Y_differences, first, last):
    
    fig, ax1 = plt.subplots(figsize=(24, 8))
    ax1.plot(Y_pred[first:last], label="Inferred", lw = 1)
    ax1.plot(Y_test[first:last], label="Truth", lw = 2, linestyle="--")
    ax1.plot(Y_differences[first:last], label="Absolute deviation", lw = 1, linestyle="-.")
    ax1.set_ylabel("x")
    ax1.set_xlabel("time")
    ax1.set_title("Lorenz attractor x component inferred value")
    plt.legend()
    plt.show()

# %% [markdown]
# ## 2.2 Coordinate reconstruction and lobe detection

# %%
(Y_pred, Y_test, Y_differences, shift, readout) = general_reconstruction(X = X, train_steps = train_steps, warm_steps = warm_steps, n_leaps = 1, leap_len = 150, delay = 20, 
                                                                         order = 2, strides = 20, ridge = 1e-2, verb = True)
# Out:
# Running Model-1:   0%|                                    | 0/1 [00:00<?, ?it/s]
# Running Model-1:   0%|                                    | 0/1 [00:00<?, ?it/s]
# Running Model-1: 360it [00:00, 3597.54it/s]
# Running Model-1: 735it [00:00, 3681.90it/s]
# Running Model-1: 1134it [00:00, 3820.60it/s]
# Running Model-1: 1550it [00:00, 3952.93it/s]
# Running Model-1: 1946it [00:00, 3948.54it/s]
# Running Model-1: 2355it [00:00, 3996.07it/s]
# Running Model-1: 2764it [00:00, 4025.63it/s]
# Running Model-1: 3167it [00:00, 4003.40it/s]
# Running Model-1: 3591it [00:00, 4076.34it/s]
# Running Model-1: 4003it [00:01, 4088.56it/s]
# Running Model-1: 4412it [00:01, 4035.57it/s]
# Running Model-1: 4816it [00:01, 4033.44it/s]
# Running Model-1: 5223it [00:01, 4043.61it/s]
# Running Model-1: 5634it [00:01, 4058.67it/s]
# Running Model-1: 6053it [00:01, 4093.61it/s]
# Running Model-1: 6463it [00:01, 4081.87it/s]
# Running Model-1: 6872it [00:01, 4016.17it/s]
# Running Model-1: 7284it [00:01, 4044.74it/s]
# Running Model-1: 7711it [00:01, 4110.03it/s]
# Running Model-1: 8123it [00:02, 4049.35it/s]
# Running Model-1: 8529it [00:02, 3773.64it/s]
# Running Model-1: 8911it [00:02, 3517.37it/s]
# Running Model-1: 9268it [00:02, 3521.35it/s]
# Running Model-1: 9650it [00:02, 3604.67it/s]
# Running Model-1: 10038it [00:02, 3682.08it/s]
# Running Model-1: 10409it [00:02, 3688.02it/s]
# Running Model-1: 10780it [00:02, 3636.33it/s]
# Running Model-1: 11145it [00:02, 3530.01it/s]
# Running Model-1: 11521it [00:02, 3595.38it/s]
# Running Model-1: 11882it [00:03, 3597.66it/s]
# Running Model-1: 12267it [00:03, 3671.42it/s]
# Running Model-1: 12635it [00:03, 3599.11it/s]
# Running Model-1: 12996it [00:03, 3526.79it/s]
# Running Model-1: 13350it [00:03, 3516.46it/s]
# Running Model-1: 13703it [00:03, 3501.02it/s]
# Running Model-1: 14060it [00:03, 3516.13it/s]
# Running Model-1: 14454it [00:03, 3639.02it/s]
# Running Model-1: 14864it [00:03, 3773.77it/s]
# Running Model-1: 15271it [00:04, 3859.89it/s]
# Running Model-1: 15658it [00:04, 3550.99it/s]
# Running Model-1: 16023it [00:04, 3577.03it/s]
# Running Model-1: 16426it [00:04, 3705.28it/s]
# Running Model-1: 16810it [00:04, 3742.19it/s]
# Running Model-1: 17207it [00:04, 3808.80it/s]
# Running Model-1: 17590it [00:04, 3337.58it/s]
# Running Model-1: 17936it [00:04, 3300.83it/s]
# Running Model-1: 18274it [00:04, 3124.58it/s]
# Running Model-1: 18593it [00:05, 2566.18it/s]
# Running Model-1: 18869it [00:05, 2029.62it/s]
# Running Model-1: 19100it [00:05, 2055.15it/s]
# Running Model-1: 19326it [00:05, 2082.33it/s]
# Running Model-1: 19582it [00:05, 2197.97it/s]
# Running Model-1: 19903it [00:05, 2457.09it/s]
# Running Model-1: 20162it [00:05, 2177.76it/s]
# Running Model-1: 20394it [00:06, 1949.41it/s]
# Running Model-1: 20602it [00:06, 1809.92it/s]
# Running Model-1: 20793it [00:06, 1696.29it/s]
# Running Model-1: 20969it [00:06, 1469.85it/s]
# Running Model-1: 21124it [00:06, 1395.82it/s]
# Running Model-1: 21269it [00:06, 1265.91it/s]
# Running Model-1: 21400it [00:06, 1274.59it/s]
# Running Model-1: 21531it [00:06, 1241.23it/s]
# Running Model-1: 21657it [00:07, 1169.65it/s]
# Running Model-1: 21776it [00:07, 1073.14it/s]
# Running Model-1: 21889it [00:07, 1086.94it/s]
# Running Model-1: 22035it [00:07, 1184.79it/s]
# Running Model-1: 22172it [00:07, 1233.82it/s]
# Running Model-1: 22304it [00:07, 1257.05it/s]
# Running Model-1: 22432it [00:07, 1182.55it/s]
# Running Model-1: 22553it [00:07, 1168.73it/s]
# Running Model-1: 22692it [00:07, 1227.48it/s]
# Running Model-1: 22817it [00:08, 1052.28it/s]
# Running Model-1: 22935it [00:08, 1084.95it/s]
# Running Model-1: 23048it [00:08, 1035.54it/s]
# Running Model-1: 23155it [00:08, 1031.00it/s]
# Running Model-1: 23315it [00:08, 1185.87it/s]
# Running Model-1: 23437it [00:08, 1123.77it/s]
# Running Model-1: 23552it [00:08, 1030.53it/s]
# Running Model-1: 23832it [00:08, 1494.17it/s]
# Running Model-1: 24150it [00:09, 1953.71it/s]
# Running Model-1: 24481it [00:09, 2330.96it/s]
# Running Model-1: 24798it [00:09, 2568.84it/s]
# Running Model-1: 25089it [00:09, 2665.97it/s]
# Running Model-1: 25362it [00:09, 2280.56it/s]
# Running Model-1: 25604it [00:09, 1663.98it/s]
# Running Model-1: 25803it [00:09, 1622.75it/s]
# Running Model-1: 26143it [00:09, 2014.23it/s]
# Running Model-1: 26434it [00:10, 2227.09it/s]
# Running Model-1: 26819it [00:10, 2638.27it/s]
# Running Model-1: 27189it [00:10, 2919.37it/s]
# Running Model-1: 27511it [00:10, 3000.53it/s]
# Running Model-1: 27827it [00:10, 2970.96it/s]
# Running Model-1: 28184it [00:10, 3139.52it/s]
# Running Model-1: 28555it [00:10, 3302.96it/s]
# Running Model-1: 28934it [00:10, 3444.06it/s]
# Running Model-1: 29284it [00:10, 3311.49it/s]
# Running Model-1: 29620it [00:11, 3221.93it/s]
# Running Model-1: 29946it [00:11, 3194.73it/s]
# Running Model-1: 30268it [00:11, 3163.62it/s]
# Running Model-1: 30586it [00:11, 3137.89it/s]
# Running Model-1: 30901it [00:11, 3131.00it/s]
# Running Model-1: 31235it [00:11, 3188.43it/s]
# Running Model-1: 31559it [00:11, 3202.21it/s]
# Running Model-1: 31926it [00:11, 3338.48it/s]
# Running Model-1: 32261it [00:11, 3331.74it/s]
# Running Model-1: 32612it [00:11, 3384.39it/s]
# Running Model-1: 32997it [00:12, 3521.92it/s]
# Running Model-1: 33407it [00:12, 3693.16it/s]
# Running Model-1: 33779it [00:12, 3700.05it/s]
# Running Model-1: 34150it [00:12, 3627.64it/s]
# Running Model-1: 34514it [00:12, 3046.15it/s]
# Running Model-1: 34835it [00:12, 2642.45it/s]
# Running Model-1: 35118it [00:12, 2556.80it/s]
# Running Model-1: 35476it [00:12, 2809.39it/s]
# Running Model-1: 35873it [00:12, 3111.72it/s]
# Running Model-1: 36212it [00:13, 3185.47it/s]
# Running Model-1: 36599it [00:13, 3374.44it/s]
# Running Model-1: 36975it [00:13, 3482.64it/s]
# Running Model-1: 37382it [00:13, 3651.53it/s]
# Running Model-1: 37792it [00:13, 3782.25it/s]
# Running Model-1: 38207it [00:13, 3888.80it/s]
# Running Model-1: 38599it [00:13, 3847.73it/s]
# Running Model-1: 38986it [00:13, 3404.65it/s]
# Running Model-1: 39338it [00:13, 2961.61it/s]
# Running Model-1: 39651it [00:14, 2652.33it/s]
# Running Model-1: 40012it [00:14, 2881.87it/s]
# Running Model-1: 40393it [00:14, 3118.36it/s]
# Running Model-1: 40784it [00:14, 3328.91it/s]
# Running Model-1: 41157it [00:14, 3439.54it/s]
# Running Model-1: 41519it [00:14, 3489.47it/s]
# Running Model-1: 41928it [00:14, 3662.06it/s]
# Running Model-1: 42334it [00:14, 3777.76it/s]
# Running Model-1: 42748it [00:14, 3882.73it/s]
# Running Model-1: 43155it [00:15, 3936.00it/s]
# Running Model-1: 43552it [00:15, 3522.76it/s]
# Running Model-1: 43914it [00:15, 3168.02it/s]
# Running Model-1: 44243it [00:15, 3002.79it/s]
# Running Model-1: 44553it [00:15, 2898.55it/s]
# Running Model-1: 44850it [00:15, 2860.90it/s]
# Running Model-1: 100%|████████████████████████████| 1/1 [00:15<00:00, 15.90s/it]
# Fitting node Ridge-1...
# Running NVAR-1: 100%|███████████████████| 25000/25000 [00:04<00:00, 5943.04it/s]
# Running Model-1: 199850it [00:52, 3810.73it/s]
# 1th/1 prediction step performed

# %%
(Y_test_sign, Y_pred_sign, Y_differences_sign,
           Y_pred_sign_smoothed, Y_differences_sign_smoothed,
           triggers_real, triggers_pred_smoothed, triggers_wrong,
           true_positive_rate, false_positive_rate, false_negative_rate
          ) = accuracy_detector(Y_pred = Y_pred, Y_test = Y_test, window = 300, tolerance = 0.51, ranger = 100, groupsize = 300)

# %%
print(true_positive_rate, false_positive_rate, false_negative_rate)
# Out:
# 0.9545454545454546 0.045454545454545456 0.045454545454545456

# %% [markdown]
# #### Trajectory reconstruction

# %%
general_comparer(Y_pred, Y_test, Y_differences, first = 0, last = 50000)

# %% [markdown]
# #### Lobe identification

# %% [markdown]
# general_comparer(Y_test = Y_test_sign, Y_pred = Y_pred_sign, Y_differences = Y_differences_sign + 2, first = 0, last = 50000)

# %% [markdown]
# #### Cleaned signal
#
# The irrealistic lobe switchings (the ones that happen too quickly) are discarded

# %%
general_comparer(Y_test = Y_test_sign, Y_pred = Y_pred_sign_smoothed, Y_differences = Y_differences_sign_smoothed + 2, first = 0, last = 50000)

# %% [markdown]
# #### Lobe switching triggers
#
# Taking the backward derivative of the previous signal, we obtain triggers for the lobe switchings

# %%
general_comparer(Y_test = -triggers_real, Y_pred = triggers_pred_smoothed, Y_differences = triggers_wrong + 2, first = 0, last = 50000)
